# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv("movie_dataset.csv")

# %%
df
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
df['production_companies']
# Out:
# 0       [{"name": "Ingenious Film Partners", "id": 289...
# 1       [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2       [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3       [{"name": "Legendary Pictures", "id": 923}, {"...
# 4             [{"name": "Walt Disney Pictures", "id": 2}]
#                               ...
# 4798             [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                   []
# 4800    [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                   []
# 4802    [{"name": "rusty bear entertainment", "id": 87...
# Name: production_companies, Length: 4803, dtype: object

# %%
print((df['production_companies'][1]))
# Out:
# [{"name": "Walt Disney Pictures", "id": 2}, {"name": "Jerry Bruckheimer Films", "id": 130}, {"name": "Second Mate Productions", "id": 19936}]

# %%
li = list()
for i in range(4803):
    li.append(df['production_companies'][i])

# %%
for i in li:
    print(type(i))
    break
# Out:
# <class 'str'>

# %%
print(len(li))
# Out:
# 4803

# %%
li[-1]
# Out:
# '[{"name": "rusty bear entertainment", "id": 87986}, {"name": "lucky crow films", "id": 87987}]'

# %%
phouse = list()
for i in li:
    if "marvel" in i.lower():
        phouse.append("Marvel")
    elif "dc" in i.lower():
        phouse.append("Dc")
    else:
        phouse.append("Neither")

print(phouse)
# Out:
# ['Neither', 'Neither', 'Neither', 'Dc', 'Neither', 'Marvel', 'Neither', 'Marvel', 'Neither', 'Dc', 'Dc', 'Neither', 'Neither', 'Neither', 'Dc', 'Neither', 'Marvel', 'Neither', 'Neither', 'Neither', 'Marvel', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Marvel', 'Neither', 'Neither', 'Neither', 'Marvel', 'Marvel', 'Neither', 'Marvel', 'Neither', 'Neither', 'Neither', 'Neither', 'Marvel', 'Neither', 'Neither', 'Dc', 'Neither', 'Neither', 'Neither', 'Neither', 'Marvel', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Marvel', 'Dc', 'Neither', 'Neither', 'Marvel', 'Neither', 'Neither', 'Neither', 'Dc', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Marvel', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Marvel', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Neither', 'Marvel', 'N
# ...

# %%
print(phouse.count("Dc"))
print(phouse.count("Marvel"))
print(phouse.count("Neither"))
# Out:
# 67
# 38
# 4698

# %%
df['Production(Dc or Marvel)'] = phouse

# %%
df
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
year = list()
for i in df['release_date']:
    print(i[:4])
    year.append((i[:4]))
# Out:
# 2009
# 2007
# 2015
# 2012
# 2012
# 2007
# 2010
# 2015
# 2009
# 2016
# 2006
# 2008
# 2006
# 2013
# 2013
# 2008
# 2012
# 2011
# 2012
# 2014
# 2012
# 2010
# 2013
# 2007
# 2005
# 1997
# 2016
# 2012
# 2015
# 2012
# 2004
# 2013
# 2010
# 2006
# 2013
# 2009
# 2014
# 2013
# 2014
# 2010
# 2011
# 2011
# 2010
# 2009
# 2015
# 2013
# 2014
# 2013
# 2013
# 2013
# 2010
# 2013
# 2011
# 2008
# 2015
# 2012
# 2016
# 2008
# 2007
# 2009
# 2009
# 2015
# 2016
# 2005
# 2016
# 2008
# 2009
# 2009
# 2008
# 2011
# 1999
# 2008
# 2016
# 2007
# 2014
# 1995
# 2009
# 2015
# 2016
# 2010
# 2012
# 2014
# 2014
# 2015
# 2013
# 2014
# 2010
# 2015
# 2014
# 2012
# 2004
# 2016
# 2010
# 2003
# 2014
# 2014
# 2010
# 2016
# 2012
# 2001
# 2008
# 2011
# 2015
# 2010
# 2006
# 2016
# 2007
# 2016
# 2015
# 2010
# 2001
# 2007
# 2004
# 2007
# 2005
# 2008
# 2007
# 2005
# 2007
# 2005
# 2008
# 2009
# 2009
# 2003
# 2013
# 2003
# 2013
# 2015
# 2009
# 2011
# 2008
# 2009
# 2012
# 2012
# 2015
# 2010
# 2007
# 2011
# 2010
# 2006
# 2013
# 2011
# ...

# %%
print(len(year))
# Out:
# 4553

# %%
df.shape
# Out:
# (4803, 25)

# %%
revenue_mar = 0
revenue_dc = 0

# %%
df
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
for i in range(4803):
    print(df.iloc[i], ['title'])
# Out:
# index                                                                       0
# budget                                                              237000000
# genres                               Action Adventure Fantasy Science Fiction
# homepage                                          http://www.avatarmovie.com/
# id                                                                      19995
# keywords                    culture clash future space war space colony so...
# original_language                                                          en
# original_title                                                         Avatar
# overview                    In the 22nd century, a paraplegic Marine is di...
# popularity                                                         150.437577
# production_companies        [{"name": "Ingenious Film Partners", "id": 289...
# production_countries        [{"iso_3166_1": "US", "name": "United States o...
# ...

# %%
df
