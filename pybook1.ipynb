# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
df_movies = pd.read_csv("movie_dataset.csv")

# %%
df_movies.shape
# Out:
# (4803, 24)

# %%
list(df_movies.columns)
# Out:
# ['index',
#  'budget',
#  'genres',
#  'homepage',
#  'id',
#  'keywords',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'revenue',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'vote_average',
#  'vote_count',
#  'cast',
#  'crew',
#  'director']

# %%
maximum_runtime = max(df_movies['runtime'])

# %%
result = df_movies[df_movies['runtime'] == maximum_runtime]

# %%
result
# Out:
#       index    budget                        genres homepage     id  \
# 2384   2384  18000000  Crime Drama Thriller History      NaN  43434
#
#                                     keywords original_language original_title  \
# 2384  gun car bomb miniseries terrorism opec                en         Carlos
#
#                                                overview  popularity  \
# 2384  The story of Venezuelan revolutionary, Ilich R...    1.138383
#
#                                    production_companies  \
# 2384  [{"name": "Egoli Tossell Film AG", "id": 2254}...
#
#                                    production_countries release_date  revenue  \
# 2384  [{"iso_3166_1": "FR", "name": "France"}, {"iso...   2010-05-19   871279
#
#       runtime                                   spoken_languages    status  \
# 2384    338.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
#
#                              tagline   title  vote_average  vote_count  \
# ...

# %%
runtimes = list(set(df_movies['runtime']))

# %%
runtimes
# Out:
# [0.0,
#  nan,
#  nan,
#  14.0,
#  25.0,
#  41.0,
#  42.0,
#  46.0,
#  47.0,
#  53.0,
#  59.0,
#  60.0,
#  63.0,
#  64.0,
#  66.0,
#  67.0,
#  68.0,
#  69.0,
#  70.0,
#  72.0,
#  73.0,
#  74.0,
#  75.0,
#  76.0,
#  77.0,
#  78.0,
#  79.0,
#  80.0,
#  81.0,
#  82.0,
#  83.0,
#  84.0,
#  85.0,
#  86.0,
#  87.0,
#  88.0,
#  89.0,
#  90.0,
#  91.0,
#  92.0,
#  93.0,
#  94.0,
#  95.0,
#  96.0,
#  97.0,
#  98.0,
#  99.0,
#  100.0,
#  101.0,
#  102.0,
#  103.0,
#  104.0,
#  105.0,
#  106.0,
#  107.0,
#  108.0,
#  109.0,
#  110.0,
#  111.0,
#  112.0,
#  113.0,
#  114.0,
#  115.0,
#  116.0,
#  117.0,
#  118.0,
#  119.0,
#  120.0,
#  121.0,
#  122.0,
#  123.0,
#  124.0,
#  125.0,
#  126.0,
#  127.0,
#  128.0,
#  129.0,
#  130.0,
#  131.0,
#  132.0,
#  133.0,
#  134.0,
#  135.0,
#  136.0,
#  137.0,
#  138.0,
#  139.0,
#  140.0,
#  141.0,
#  142.0,
#  143.0,
#  144.0,
#  145.0,
#  146.0,
#  147.0,
#  148.0,
#  149.0,
#  150.0,
#  151.0,
#  152.0,
#  153.0,
#  154.0,
#  155.0,
#  156.0,
#  157.0,
# ...

# %%
runtimes
